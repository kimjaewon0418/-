# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ad = pd.read_csv('/content/eda_ad.csv')
order = pd.read_csv('/content/eda_order.csv')
purchase = pd.read_csv('/content/eda_purchase.csv')
product = pd.read_csv('/content/eda_product.csv')
visit = pd.read_csv('/content/eda_visit.csv')

# %%
order.head()
# Out:
#    order_id  user_id  product_id  order_date  quantity  discount_ratio  \
# 0       1.0    960.0        17.0  2023-02-07       6.0        0.004746
# 1       6.0   1447.0         6.0  2023-01-12       6.0        0.008240
# 2      14.0   1325.0        17.0  2023-02-15       6.0        0.039391
# 3      17.0    102.0         1.0  2023-02-20       6.0        0.007944
# 4      38.0     94.0         8.0  2023-02-11       6.0        0.014037
#
#      pay_date
# 0  2023-02-09
# 1  2023-01-14
# 2         NaN
# 3  2023-02-26
# 4  2023-02-13

# %%
order['order_date'] = pd.to_datetime(order.order_date)
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        5000 non-null   float64
#  1   user_id         5000 non-null   float64
#  2   product_id      5000 non-null   float64
#  3   order_date      5000 non-null   datetime64[ns]
#  4   quantity        5000 non-null   float64
#  5   discount_ratio  5000 non-null   float64
#  6   pay_date        3738 non-null   object
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 273.6+ KB

# %%
order.head()
# Out:
#    order_id  user_id  product_id order_date  quantity  discount_ratio  \
# 0       1.0    960.0        17.0 2023-02-07       6.0        0.004746
# 1       6.0   1447.0         6.0 2023-01-12       6.0        0.008240
# 2      14.0   1325.0        17.0 2023-02-15       6.0        0.039391
# 3      17.0    102.0         1.0 2023-02-20       6.0        0.007944
# 4      38.0     94.0         8.0 2023-02-11       6.0        0.014037
#
#      pay_date
# 0  2023-02-09
# 1  2023-01-14
# 2         NaN
# 3  2023-02-26
# 4  2023-02-13

# %%
product.head()
# Out:
#    id category  cost  price
# 0   1        b    23     48
# 1   2        e    19     40
# 2   3        a    17     35
# 3   4        b    32     56
# 4   5        a    11     25

# %%
ad['date'] = pd.to_datetime(ad.date)
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      50000 non-null  datetime64[ns]
#  1   campaign  50000 non-null  object
#  2   source    50000 non-null  object
#  3   spending  50000 non-null  float64
#  4   clicks    50000 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(2)
# memory usage: 1.9+ MB

# %%
purchase['timestamp'] = pd.to_datetime(purchase.timestamp)
purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    4500 non-null   float64
#  1   order_id   4500 non-null   float64
#  2   timestamp  4500 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 105.6 KB

# %%
visit['timestamp'] = pd.to_datetime(visit.timestamp)
visit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2219 entries, 0 to 2218
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_id    2219 non-null   float64
#  1   source     1125 non-null   object
#  2   campaign   1125 non-null   object
#  3   timestamp  2219 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 69.5+ KB

# %%
order.head()
# Out:
#    order_id  user_id  product_id order_date  quantity  discount_ratio  \
# 0       1.0    960.0        17.0 2023-02-07       6.0        0.004746
# 1       6.0   1447.0         6.0 2023-01-12       6.0        0.008240
# 2      14.0   1325.0        17.0 2023-02-15       6.0        0.039391
# 3      17.0    102.0         1.0 2023-02-20       6.0        0.007944
# 4      38.0     94.0         8.0 2023-02-11       6.0        0.014037
#
#      pay_date
# 0  2023-02-09
# 1  2023-01-14
# 2         NaN
# 3  2023-02-26
# 4  2023-02-13

# %%
product.head()
# Out:
#    id category  cost  price
# 0   1        b    23     48
# 1   2        e    19     40
# 2   3        a    17     35
# 3   4        b    32     56
# 4   5        a    11     25

# %%
order_mg = pd.merge(order, product, how='left', left_on = 'product_id', right_on = 'id')

# %%
order_mg['total_revenue'] = order_mg.price * order_mg.quantity
order_mg['total_disc_amt'] = order_mg.total_revenue * order_mg.discount_ratio
order_mg['total_cost'] = order_mg.cost * order_mg.quantity
order_mg['total_profit'] = order_mg.total_revenue - order_mg.total_cost - order_mg.total_disc_amt

# %%
visit_nn = ~visit.campaign.isna()
visit[visit_nn]
# Out:
#       user_id source     campaign                     timestamp
# 2      1017.0      b   campaign_8 2023-02-08 13:10:49.026771200
# 3      1398.0      b   campaign_6 2023-01-07 06:37:27.756224000
# 6       707.0      b   campaign_5 2023-01-21 10:51:52.800867200
# 10     1285.0      a   campaign_3 2023-01-06 11:49:36.565366400
# 18      529.0      b   campaign_7 2023-01-28 12:51:38.503680000
# ...       ...    ...          ...                           ...
# 2200    869.0      b  campaign_10 2022-12-29 07:21:02.435923200
# 2210    979.0      b   campaign_9 2022-11-28 08:55:33.216025600
# 2211    979.0      b   campaign_6 2023-04-12 08:34:58.723929600
# 2212    979.0      b   campaign_4 2023-01-19 09:58:04.480480000
# 2218    868.0      b   campaign_9 2023-02-14 18:53:30.268672000
#
# [1125 rows x 4 columns]

# %%
log_mg = pd.merge(purchase, visit, how='cross')

# %%
log_mg.rename(
    columns = {
        'user_id_x':'user_id_pruc',
        'user_id_vist':'user_id_visit',
        'timestamp_x':'pruc_at',
        'timestamp_y':'visit_at'
    }
    , inplace= True
)

# %%
log_mg
# Out:
#          user_id_pruc  order_id             pruc_at  user_id_visit source  \
# 0               960.0       1.0 2023-02-07 18:13:21         1017.0    NaN
# 1               960.0       1.0 2023-02-07 18:13:21         1017.0    NaN
# 2               960.0       1.0 2023-02-07 18:13:21         1017.0      b
# 3               960.0       1.0 2023-02-07 18:13:21         1398.0      b
# 4               960.0       1.0 2023-02-07 18:13:21         1398.0    NaN
# ...               ...       ...                 ...            ...    ...
# 9985495         926.0    4808.0 2023-02-25 11:22:04           19.0    NaN
# 9985496         926.0    4808.0 2023-02-25 11:22:04           19.0    NaN
# 9985497         926.0    4808.0 2023-02-25 11:22:04           19.0    NaN
# 9985498         926.0    4808.0 2023-02-25 11:22:04          868.0    NaN
# 9985499         926.0    4808.0 2023-02-25 11:22:04          868.0      b
#
#            campaign                      visit_at
# 0               NaN 2022-12-15 13:06:36.361808000
# 1               NaN 2023-02-20 02:46:59.416083200
# 2        campaign_8 2023-02-08 13:10:49.026771200
# 3        campaign_6 2023-01-07 06:37:27.756224000
# 4               NaN 2023-01-19 00:49:56.166291200
# ...             ...                           ...
# 9985495         NaN 2022-12-31 02:33:28.486646400
# 9985496         NaN 2023-04-19 06:42:09.471859200
# 9985497         NaN 2023-01-20 02:39:59.212771200
# 9985498         NaN 2023-01-08 04:00:25.681513600
# 9985499  campaign_9 2023-02-14 18:53:30.268672000
#
# [9985500 rows x 7 columns]

# %%
same_user = log_mg.user_id_pruc == log_mg.user_id_visit
same_user
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#            ...
# 9985495    True
# 9985496    True
# 9985497    True
# 9985498    True
# 9985499    True
# Length: 9985500, dtype: bool

# %%
time_filter = log_mg.pruc_at >= log_mg.visit_at
time_filter
# Out:
# 0           True
# 1          False
# 2          False
# 3           True
# 4           True
#            ...
# 9985495     True
# 9985496    False
# 9985497     True
# 9985498     True
# 9985499     True
# Length: 9985500, dtype: bool

# %%
log_mg['td_day'] = (log_mg.pruc_at - log_mg.visit_at).dt.total_seconds()/(3600*24)

# %%
attr_w = log_mg.td_day <= 70

# %%
log = log_mg[same_user &time_filter &attr_w]

# %%
log.reset_index(drop=True,inplace=True)
